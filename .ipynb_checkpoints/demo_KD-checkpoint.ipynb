# %% [markdown]
# # 1、Install
#
# `cd KD_package`
#
# `python setup.py install`

# %% [markdown]
# # 2、Data Visualization

# %%
import pandas as pd
df_acc = pd.read_csv('data/gene/ACC.csv')
df_acc_gene = pd.read_csv('data/cancer_gene/ACC_data.csv')

# %%
df_acc.head()
# Out:
#       sample_id cancer_type  os_status  os_time
# 0  TCGA-OR-A5J1         ACC          1     1355
# 1  TCGA-OR-A5J2         ACC          1     1677
# 2  TCGA-OR-A5J3         ACC          0     2091
# 3  TCGA-OR-A5J5         ACC          1      365
# 4  TCGA-OR-A5J6         ACC          0     2703

# %%
# the number of samples * 4
df_acc.shape
# Out:
# (79, 4)

# %%
df_acc_gene.head()
# Out:
#    TCGA-OR-A5J1  TCGA-OR-A5J2  TCGA-OR-A5J3  TCGA-OR-A5J5  TCGA-OR-A5J6  \
# 0       62.1323       72.4692       43.6827       10.4420       59.6585
# 1        0.0427        0.0362        0.0947        0.0238        0.0000
# 2        2.7157        3.1569        1.0242        3.8207       21.7899
# 3        3.8876        3.1952       14.3955        2.1786        4.2493
# 4        2.2845        0.6416        0.7176        1.3663        0.4141
#
#    TCGA-OR-A5J7  TCGA-OR-A5J8  TCGA-OR-A5J9  TCGA-OR-A5JA  TCGA-OR-A5JB  ...  \
# 0       75.4212      191.0045      108.4004       48.4416       20.1700  ...
# 1        0.0364        0.0559        0.1333        0.0239        0.0212  ...
# 2        2.8414       18.8781        6.3364        9.3061       48.2604  ...
# 3       16.6906        1.6975        8.4572        7.3308        3.6709  ...
# 4        0.6212        2.7539        1.9518        0.7069        0.4447  ...
#
# ...

# %%
#  dimension of gene * the number of samples
df_acc_gene.shape
# Out:
# (5796, 79)

# %% [markdown]
# # 3、Train
# ### We provide a simple approach to train model on your own data, as long as the data is organized according to the above format.

# %%
from KD.experiment import KD_Trainer, KDKA_Trainer
# For more details about parameters, please refer to the github repository.
# train = KDKA_Trainer(cancer_type='ACC', folder='data/cancer_gene/', resume='', csv_folder='data/', round=25, batch_size=10, output_folder='pth', lr=0.1, dim=5796, seed=42)
train = KD_Trainer(cancer_type='ACC', folder='data/cancer_gene/', resume='', csv_folder='data/', round=25, batch_size=10, output_folder='pth', lr=0.1, dim=5796, seed=42)

# %%
train.train()
# Out:
# Cancer Type: ACC
# Start distillation!
# ...
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 321.65it/s]
# 0
# Start Final Training!
# ROUND:0
# ...
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 10.48it/s]
# Cancer: ACC Round: 0 Cindex: 0.8823529410467129
# ROUND:1
# ...
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00,  9.70it/s]
# Cancer: ACC Round: 1 Cindex: 0.91176470574827
# ROUND:2
# ...
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 10.50it/s]
# Cancer: ACC Round: 2 Cindex: 0.9264705880990485
# ROUND:3
# ...
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 10.49it/s]
# Cancer: ACC Round: 3 Cindex: 0.91176470574827
# ROUND:4
# ...
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 10.06it/s]
# Cancer: ACC Round: 4 Cindex: 0.91176470574827
# ROUND:5
# ...
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 10.07it/s]
# ...

# %% [markdown]
# # 4、Evaluate
# ### We provide two configurations for inference, one is to do inference on all data, and the other is to do cross-validation.

# %%
from KD.experiment import Evaluate
# For more details about parameters, please refer to the github repository.
evaluate = Evaluate(cancer_type='ACC', folder='data/cancer_gene/', resume='pth/final/ACC.pth', csv_folder='data/', round=2, seed=42)

# %%
evaluate.eval(cv=True)
# Out:
# Cancer Type: ACC
# Load Model!
# ROUND:0
# Cancer: ACC Round: 0 Cindex: 0.9558823528006056
# ROUND:1
# Cancer: ACC Round: 1 Cindex: 0.8499999998937501

# %%
evaluate.eval(cv=False)
# Out:
# Cancer Type: ACC
# Load Model!
# Cancer: ACC Cindex: 0.8606726149563441
